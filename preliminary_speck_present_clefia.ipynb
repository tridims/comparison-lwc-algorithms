# %% [markdown]
# ## Preliminary Test Algoritma Speck, Clefia, dan Present

# %% [markdown]
# ### Test Data

# %%
test_data = [
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon about',
    'legal winner thank year wave sausage worth useful legal winner thank yellow',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage above',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo wrong',
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon agent',
    'legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal will',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter always',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo when',
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon art',
    'legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth title',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic bless',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo vote',
    'ozone drill grab fiber curtain grace pudding thank cruise elder eight picnic',
    'gravity machine north sort system female filter attitude volume fold club stay feature office ecology stable narrow fog',
    'hamster diagram private dutch cause delay private meat slide toddler razor book happy fancy gospel tennis maple dilemma loan word shrug inflict delay length',
    'scheme spot photo card baby mountain device kick cradle pact join borrow',
    'horn tenant knee talent sponsor spell gate clip pulse soap slush warm silver nephew swap uncle crack brave',
    'panda eyebrow bullet gorilla call smoke muffin taste mesh discover soft ostrich alcohol speed nation flash devote level hobby quick inner drive ghost inside',
    'cat swing flag economy stadium alone churn speed unique patch report train',
    'light rule cinnamon wrap drastic word pride squirrel upgrade then income fatal apart sustain crack supply proud access',
    'all hour make first leader extend hole alien behind guard gospel lava path output census museum junior mass reopen famous sing advance salt reform',
    'vessel ladder alter error federal sibling chat ability sun glass valve picture',
    'scissors invite lock maple supreme raw rapid void congress muscle digital elegant little brisk hair mango congress clump',
    'void come effort suffer camp survey warrior heavy shoot primary clutch crush open amazing screen patrol group space point ten exist slush involve unfold',
    "abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace agrese",
    "abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abeille",
    "abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abete",
    "あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あおぞら",
    "가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가능",
    "abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abater",
]

# %%
# random key for testing
import secrets
_key_data = [secrets.token_bytes(256 >> 3) for _ in range(30)]

# %% [markdown]
# ### Pengujian Performa Preliminary - Waktu Eksekusi

# %%
from prelim2 import *
import time
import pandas as pd

# Initialize a dictionary to store the results
results = {}
key_data = _key_data.copy()

# Iterate over the test data
for i, plaintext in enumerate(test_data):
    results[plaintext] = {}
    results[plaintext]["Key"] = to_hex(_key_data[i])

    # Test Speck cipher
    for mode in MODE_OF_OPERATIONS:
        speck_cipher = Speck(key_data[i])

        # Measure encryption time
        start_time = time.time()
        operate_block_mode(mode, speck_cipher, plaintext)
        end_time = time.time()

        # Calculate encryption time in milliseconds
        encryption_time_ms = (end_time - start_time) * 1000

        # Store the result in the dictionary
        results[plaintext][f"Speck_{mode}"] = encryption_time_ms
    
    # Test Present cipher
    for mode in MODE_OF_OPERATIONS:
        present_cipher = Present(key_data[i][:16])

        # Measure encryption time
        start_time = time.time()
        operate_block_mode(mode, present_cipher, plaintext)
        end_time = time.time()

        # Calculate encryption time in milliseconds
        encryption_time_ms = (end_time - start_time) * 1000

        # Store the result in the dictionary
        results[plaintext][f"Present_{mode}"] = encryption_time_ms
    
    # Test Clefia cipher
    for mode in MODE_OF_OPERATIONS:
        clefia_cipher = Clefia(key_data[i])

        # Measure encryption time
        start_time = time.time()
        operate_block_mode(mode, clefia_cipher, plaintext)
        end_time = time.time()

        # Calculate encryption time in milliseconds
        encryption_time_ms = (end_time - start_time) * 1000

        # Store the result in the dictionary
        results[plaintext][f"Clefia_{mode}"] = encryption_time_ms


# Create a pandas DataFrame from the results
df = pd.DataFrame.from_dict(results, orient="index")

# Save the DataFrame to a CSV file
df.to_csv("encryption_times_prelim_2.csv", index_label="Plaintext")

# %% [markdown]
# ### Pengujian Keamanan Preliminary - Avalanche Effect

# %%
test_data = [
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon about',
    'legal winner thank year wave sausage worth useful legal winner thank yellow',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage above',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo wrong',
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon agent',
    'legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal will',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter always',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo when',
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon art',
    'legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth title',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic bless',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo vote',
    'ozone drill grab fiber curtain grace pudding thank cruise elder eight picnic',
    'gravity machine north sort system female filter attitude volume fold club stay feature office ecology stable narrow fog',
    'hamster diagram private dutch cause delay private meat slide toddler razor book happy fancy gospel tennis maple dilemma loan word shrug inflict delay length',
    'scheme spot photo card baby mountain device kick cradle pact join borrow',
    'horn tenant knee talent sponsor spell gate clip pulse soap slush warm silver nephew swap uncle crack brave',
    'panda eyebrow bullet gorilla call smoke muffin taste mesh discover soft ostrich alcohol speed nation flash devote level hobby quick inner drive ghost inside',
    'cat swing flag economy stadium alone churn speed unique patch report train',
    'light rule cinnamon wrap drastic word pride squirrel upgrade then income fatal apart sustain crack supply proud access',
    'all hour make first leader extend hole alien behind guard gospel lava path output census museum junior mass reopen famous sing advance salt reform',
    'vessel ladder alter error federal sibling chat ability sun glass valve picture',
    'scissors invite lock maple supreme raw rapid void congress muscle digital elegant little brisk hair mango congress clump',
    'void come effort suffer camp survey warrior heavy shoot primary clutch crush open amazing screen patrol group space point ten exist slush involve unfold',
    "abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace agrese",
    "abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abeille",
    "abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abete",
    "あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あおぞら",
    "가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가능",
    "abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abater",
]

modified_data = [
    'legal abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon',
    'letter winner thank year wave sausage worth useful legal winner thank yellow',
    'zoo advice cage absurd amount doctor acoustic avoid letter advice cage above',
    'abandon zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo',
    'legal abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon',
    'letter winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal will',
    'zoo advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter always',
    'abandon zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo',
    'legal abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon',
    'letter winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth title',
    'zoo advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic bless',
    'ozone zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo',
    'machine drill grab fiber curtain grace pudding thank cruise elder eight picnic',
    'hamster machine north sort system female filter attitude volume fold club stay feature office ecology stable narrow fog',
    'scheme diagram private dutch cause delay private meat slide toddler razor book happy fancy gospel tennis maple dilemma loan word shrug inflict delay length',
    'horn spot photo card baby mountain device kick cradle pact join borrow',
    'panda tenant knee talent sponsor spell gate clip pulse soap slush warm silver nephew swap uncle crack brave',
    'cat eyebrow bullet gorilla call smoke muffin taste mesh discover soft ostrich alcohol speed nation flash devote level hobby quick inner drive ghost inside',
    'light swing flag economy stadium alone churn speed unique patch report train',
    'all rule cinnamon wrap drastic word pride squirrel upgrade then income fatal apart sustain crack supply proud access',
    'vessel hour make first leader extend hole alien behind guard gospel lava path output census museum junior mass reopen famous sing advance salt reform',
    'scissors ladder alter error federal sibling chat ability sun glass valve picture',
    'void invite lock maple supreme raw rapid void congress muscle digital elegant little brisk hair mango congress clump',
    'abdikace come effort suffer camp survey warrior heavy shoot primary clutch crush open amazing screen patrol group space point ten exist slush involve unfold',
    "abaisser abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace",
    "abaco abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser",
    "abacate abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco",
    "あおぞら　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん",
    "가능 가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가격",
    "abaisser abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate",
]


# make sure the modified data is not the same
for i in range(len(test_data)):
    assert test_data[i] != modified_data[i]

# %%
def calculate_avalanche_effect(ciphertext1, ciphertext2):
    ciphertext1_bin = bin(int.from_bytes(ciphertext1, 'big'))[2:]
    ciphertext2_bin = bin(int.from_bytes(ciphertext2, 'big'))[2:]

    # Pad the shorter binary string with zeros if the lengths are unequal
    max_len = max(len(ciphertext1_bin), len(ciphertext2_bin))
    ciphertext1_bin = ciphertext1_bin.zfill(max_len)
    ciphertext2_bin = ciphertext2_bin.zfill(max_len)

    diff_bits = sum(bit1 != bit2 for bit1, bit2 in zip(ciphertext1_bin, ciphertext2_bin))
    total_bits = len(ciphertext1_bin)
    avalanche_effect = diff_bits / total_bits
    return avalanche_effect

# %%
from prelim2 import *
import pandas as pd

# Initialize a dictionary to store the results
results = {}
key_data = _key_data.copy()

# Iterate over the test data and modified data
for plaintext, modified_plaintext in zip(test_data, modified_data):
    results[plaintext] = {}
    key = key_data.pop()
    results[plaintext]["Modified_Plaintext"] = modified_plaintext
    results[plaintext]["Key"] = to_hex(key)
    
    # Test Speck cipher
    for mode in MODE_OF_OPERATIONS:
        speck_cipher = Speck(key)
        
        ciphertext = encrypt_using_block_mode(mode, speck_cipher, plaintext)
        modified_ciphertext = encrypt_using_block_mode(mode, speck_cipher, modified_plaintext)

        # Calculate avalanche effect
        avalanche_effect = calculate_avalanche_effect(ciphertext, modified_ciphertext)
        
        # Store the results in the dictionary
        results[plaintext][f"Speck_{mode}_Avalanche"] = avalanche_effect
    
    # Test Present cipher
    for mode in MODE_OF_OPERATIONS:
        present_cipher = Present(key[:16])
        
        ciphertext = encrypt_using_block_mode(mode, present_cipher, plaintext)
        modified_ciphertext = encrypt_using_block_mode(mode, present_cipher, modified_plaintext)
        
        # Calculate avalanche effect
        avalanche_effect = calculate_avalanche_effect(ciphertext, modified_ciphertext)
        
        # Store the results in the dictionary
        results[plaintext][f"Present_{mode}_Avalanche"] = avalanche_effect
    
    # Test Clefia cipher
    for mode in MODE_OF_OPERATIONS:
        clefia_cipher = Clefia(key)
        
        ciphertext = encrypt_using_block_mode(mode, clefia_cipher, plaintext)
        modified_ciphertext = encrypt_using_block_mode(mode, clefia_cipher, modified_plaintext)
        
        # Calculate avalanche effect
        avalanche_effect = calculate_avalanche_effect(ciphertext, modified_ciphertext)
        
        # Store the results in the dictionary
        results[plaintext][f"Clefia_{mode}_Avalanche"] = avalanche_effect

# Create a pandas DataFrame from the results
df = pd.DataFrame.from_dict(results, orient="index")

# Save the DataFrame to a CSV file
df.to_csv("avalanche_effect_results_prelim_2.csv", index_label="Plaintext")

# %% [markdown]
# # Test Avalanche 2

# %%
test_data = [
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon about',
    'legal winner thank year wave sausage worth useful legal winner thank yellow',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage above',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo wrong',
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon agent',
    'legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal will',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter always',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo when',
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon art',
    'legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth title',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic bless',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo vote',
    'ozone drill grab fiber curtain grace pudding thank cruise elder eight picnic',
    'gravity machine north sort system female filter attitude volume fold club stay feature office ecology stable narrow fog',
    'hamster diagram private dutch cause delay private meat slide toddler razor book happy fancy gospel tennis maple dilemma loan word shrug inflict delay length',
    'scheme spot photo card baby mountain device kick cradle pact join borrow',
    'horn tenant knee talent sponsor spell gate clip pulse soap slush warm silver nephew swap uncle crack brave',
    'panda eyebrow bullet gorilla call smoke muffin taste mesh discover soft ostrich alcohol speed nation flash devote level hobby quick inner drive ghost inside',
    'cat swing flag economy stadium alone churn speed unique patch report train',
    'light rule cinnamon wrap drastic word pride squirrel upgrade then income fatal apart sustain crack supply proud access',
    'all hour make first leader extend hole alien behind guard gospel lava path output census museum junior mass reopen famous sing advance salt reform',
    'vessel ladder alter error federal sibling chat ability sun glass valve picture',
    'scissors invite lock maple supreme raw rapid void congress muscle digital elegant little brisk hair mango congress clump',
    'void come effort suffer camp survey warrior heavy shoot primary clutch crush open amazing screen patrol group space point ten exist slush involve unfold',
    "abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace agrese",
    "abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abeille",
    "abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abete",
    "あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あおぞら",
    "가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가능",
    "abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abater",
]

modified_data = [
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon legal',
    'legal winner thank year wave sausage worth useful legal winner thank letter',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage zoo',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo abandon',
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon legal',
    'legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal letter',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter zoo',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo abandon',
    'abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon abandon legal',
    'legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth useful legal winner thank year wave sausage worth letter',
    'letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic avoid letter advice cage absurd amount doctor acoustic zoo',
    'zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo zoo ozone',
    'ozone drill grab fiber curtain grace pudding thank cruise elder eight machine',
    'gravity machine north sort system female filter attitude volume fold club stay feature office ecology stable narrow hamster',
    'hamster diagram private dutch cause delay private meat slide toddler razor book happy fancy gospel tennis maple dilemma loan word shrug inflict delay scheme',
    'scheme spot photo card baby mountain device kick cradle pact join horn',
    'horn tenant knee talent sponsor spell gate clip pulse soap slush warm silver nephew swap uncle crack panda',
    'panda eyebrow bullet gorilla call smoke muffin taste mesh discover soft ostrich alcohol speed nation flash devote level hobby quick inner drive ghost cat',
    'cat swing flag economy stadium alone churn speed unique patch report light',
    'light rule cinnamon wrap drastic word pride squirrel upgrade then income fatal apart sustain crack supply proud all',
    'all hour make first leader extend hole alien behind guard gospel lava path output census museum junior mass reopen famous sing advance salt vessel',
    'vessel ladder alter error federal sibling chat ability sun glass valve scissors',
    'scissors invite lock maple supreme raw rapid void congress muscle digital elegant little brisk hair mango congress void',
    'void come effort suffer camp survey warrior heavy shoot primary clutch crush open amazing screen patrol group space point ten exist slush involve abdikace',
    "abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abdikace abaisser",
    "abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaisser abaco",
    "abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abaco abacate",
    "あおぞら　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん　あいこくしん",
    "가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가격 가능 くしん",
    "abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abacate abaisser",
]

# make sure the modified data is not the same
for i in range(len(test_data)):
    assert test_data[i] != modified_data[i]

# %%
from prelim2 import *
import pandas as pd

# Initialize a dictionary to store the results
results = {}
key_data = _key_data.copy()

# Iterate over the test data and modified data
for plaintext, modified_plaintext in zip(test_data, modified_data):
    results[plaintext] = {}
    key = key_data.pop()
    results[plaintext]["Modified_Plaintext"] = modified_plaintext
    results[plaintext]["Key"] = to_hex(key)
    
    # Test Speck cipher
    for mode in MODE_OF_OPERATIONS:
        speck_cipher = Speck(key)
        
        ciphertext = encrypt_using_block_mode(mode, speck_cipher, plaintext)
        modified_ciphertext = encrypt_using_block_mode(mode, speck_cipher, modified_plaintext)

        # Calculate avalanche effect
        avalanche_effect = calculate_avalanche_effect(ciphertext, modified_ciphertext)
        
        # Store the results in the dictionary
        results[plaintext][f"Speck_{mode}_Avalanche"] = avalanche_effect
    
    # Test Present cipher
    for mode in MODE_OF_OPERATIONS:
        present_cipher = Present(key[:16])
        
        ciphertext = encrypt_using_block_mode(mode, present_cipher, plaintext)
        modified_ciphertext = encrypt_using_block_mode(mode, present_cipher, modified_plaintext)
        
        # Calculate avalanche effect
        avalanche_effect = calculate_avalanche_effect(ciphertext, modified_ciphertext)
        
        # Store the results in the dictionary
        results[plaintext][f"Present_{mode}_Avalanche"] = avalanche_effect
    
    # Test Clefia cipher
    for mode in MODE_OF_OPERATIONS:
        clefia_cipher = Clefia(key)
        
        ciphertext = encrypt_using_block_mode(mode, clefia_cipher, plaintext)
        modified_ciphertext = encrypt_using_block_mode(mode, clefia_cipher, modified_plaintext)
        
        # Calculate avalanche effect
        avalanche_effect = calculate_avalanche_effect(ciphertext, modified_ciphertext)
        
        # Store the results in the dictionary
        results[plaintext][f"Clefia_{mode}_Avalanche"] = avalanche_effect

# Create a pandas DataFrame from the results
df = pd.DataFrame.from_dict(results, orient="index")

# Save the DataFrame to a CSV file
df.to_csv("avalanche_effect_results_prelim_2_b.csv", index_label="Plaintext")
